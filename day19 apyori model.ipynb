# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("market_basket.csv" , header= None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
#pip install apyori

# %%
 #Data processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#traing the dataset
from apyori import apriori
rules = apriori(transactions ,
                min_support = 0.003 ,
                min_confidence = 0.2,
                min_lift = 3 ,        #(3items * 7 in week)/ (Total rows in dataset 7501)
                min_length = 2)

#visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0,len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
result
# Out:
# [['light cream', 'chicken'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'pasta'],
#  ['honey', 'fromage blanc'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'tomato sauce'],
#  ['light cream', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['shrimp', 'pasta'],
#  ['milk', 'spaghetti', 'avocado'],
#  ['milk', 'cake', 'burgers'],
#  ['chocolate', 'turkey', 'burgers'],
#  ['milk', 'turkey', 'burgers'],
#  ['tomatoes', 'cake', 'frozen vegetables'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['milk', 'ground beef', 'chicken'],
#  ['nan', 'light cream', 'chicken'],
#  ['olive oil', 'milk', 'chicken'],
#  ['olive oil', 'spaghetti', 'chicken'],
#  ['chocolate', 'shrimp', 'frozen vegetables'],
#  ['chocolate', 'ground beef', 'herb & pepper'],
#  ['chocolate', 'milk', 'soup'],
#  ['cooking oil', 'ground beef', 'spaghetti'],
#  ['eggs', 'ground beef', 'herb & pepper'],
#  ['eggs', 'spaghetti', 'red wine'],
#  ['escalope', 'nan', 'mushroom cream sauce'],
#  ['escalope', 'nan', 'pasta'],
#  ['ground beef', 'french fries', 'herb & pepper'],
#  ['honey', 'nan', 'fromage blanc'],
#  ['tomatoes', 'green tea', 'frozen vegetables'],
#  ['ground beef', 'frozen vegetables', 'spaghetti'],
#  ['milk', 'frozen vegetables', 'olive oil'],
#  ['milk', 'frozen vegetables', 'soup'],
#  ['milk', 'frozen vegetables', 'tomatoes'],
#  ['mineral water', 'shrimp', 'frozen vegetables'],
#  ['frozen vegetables', 'spaghetti', 'olive oil'],
#  ['shrimp', 'frozen vegetables', 'spaghetti'],
#  ['shrimp', 'frozen vegetables', 'tomatoes'],
#  ['tomatoes', 'frozen vegetables', 'spaghetti'],
#  ['grated cheese', 'ground beef', 'spaghetti'],
#  ['ground beef', 'tomatoes', 'green tea'],
#  ['milk', 'ground beef', 'herb & pepper'],
#  ['mineral water', 'ground beef', 'herb & pepper'],
#  ['nan', 'ground beef', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'herb & pepper'],
#  ['milk', 'ground beef', 'olive oil'],
#  ['milk', 'ground beef', 'soup'],
#  ['nan', 'ground beef', 'tomato sauce'],
#  ['pepper', 'ground beef', 'spaghetti'],
#  ['shrimp', 'ground beef', 'spaghetti'],
#  ['ground beef', 'spaghetti', 'tomato sauce'],
#  ['mineral water', 'spaghetti', 'light cream'],
#  ['nan', 'light cream', 'olive oil'],
#  ['milk', 'shrimp', 'olive oil'],
#  ['milk', 'soup', 'olive oil'],
#  ['milk', 'spaghetti', 'olive oil'],
#  ['milk', 'soup', 'tomatoes'],
#  ['whole wheat pasta', 'milk', 'spaghetti'],
#  ['mineral water', 'soup', 'olive oil'],
#  ['whole wheat pasta', 'mineral water', 'olive oil'],
#  ['whole wheat pasta', 'nan', 'olive oil'],
#  ['shrimp', 'nan', 'pasta'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'whole wheat rice', 'spaghetti'],
#  ['nan', 'milk', 'spaghetti', 'avocado'],
#  ['nan', 'milk', 'cake', 'burgers'],
#  ['nan', 'chocolate', 'turkey', 'burgers'],
#  ['nan', 'milk', 'turkey', 'burgers'],
#  ['nan', 'cake', 'frozen vegetables', 'tomatoes'],
#  ['cereals', 'ground beef', 'spaghetti', 'nan'],
#  ['nan', 'milk', 'ground beef', 'chicken'],
#  ['nan', 'olive oil', 'milk', 'chicken'],
#  ['olive oil', 'nan', 'spaghetti', 'chicken'],
#  ['eggs', 'chocolate', 'ground beef', 'mineral water'],
#  ['mineral water', 'chocolate', 'ground beef', 'frozen vegetables'],
#  ['chocolate', 'ground beef', 'frozen vegetables', 'spaghetti'],
#  ['mineral water', 'chocolate', 'milk', 'frozen vegetables'],
#  ['chocolate', 'milk', 'frozen vegetables', 'spaghetti'],
#  ['mineral water', 'chocolate', 'shrimp', 'frozen vegetables'],
#  ['chocolate', 'shrimp', 'frozen vegetables', 'nan'],
#  ['chocolate', 'ground beef', 'herb & pepper', 'nan'],
#  ['chocolate', 'milk', 'soup', 'nan'],
#  ['mineral water', 'chocolate', 'spaghetti', 'olive oil'],
#  ['mineral water', 'chocolate', 'shrimp', 'spaghetti'],
#  ['cooking oil', 'nan', 'ground beef', 'spaghetti'],
#  ['mineral water', 'eggs', 'milk', 'frozen vegetables'],
#  ['eggs', 'ground beef', 'herb & pepper', 'nan'],
#  ['eggs', 'spaghetti', 'red wine', 'nan'],
#  ['nan', 'ground beef', 'french fries', 'herb & pepper'],
#  ['mineral water', 'milk', 'spaghetti', 'frozen smoothie'],
#  ['nan', 'green tea', 'frozen vegetables', 'tomatoes'],
#  ['mineral water', 'milk', 'ground beef', 'frozen vegetables'],
#  ['milk', 'ground beef', 'frozen vegetables', 'spaghetti'],
#  ['mineral water', 'ground beef', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'ground beef', 'frozen vegetables', 'spaghetti'],
#  ['mineral water', 'milk', 'frozen vegetables', 'olive oil'],
#  ['mineral water', 'milk', 'frozen vegetables', 'soup'],
#  ['mineral water', 'milk', 'frozen vegetables', 'spaghetti'],
#  ['olive oil', 'milk', 'frozen vegetables', 'nan'],
#  ['soup', 'milk', 'frozen vegetables', 'nan'],
#  ['tomatoes', 'milk', 'frozen vegetables', 'nan'],
#  ['mineral water', 'nan', 'shrimp', 'frozen vegetables'],
#  ['mineral water', 'shrimp', 'frozen vegetables', 'spaghetti'],
#  ['mineral water', 'tomatoes', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'frozen vegetables', 'spaghetti', 'olive oil'],
#  ['nan', 'shrimp', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'shrimp', 'frozen vegetables', 'tomatoes'],
#  ['nan', 'frozen vegetables', 'spaghetti', 'tomatoes'],
#  ['grated cheese', 'nan', 'ground beef', 'spaghetti'],
#  ['ground beef', 'nan', 'green tea', 'tomatoes'],
#  ['milk', 'ground beef', 'herb & pepper', 'nan'],
#  ['mineral water', 'nan', 'ground beef', 'herb & pepper'],
#  ['spaghetti', 'nan', 'ground beef', 'herb & pepper'],
#  ['mineral water', 'milk', 'ground beef', 'spaghetti'],
#  ['olive oil', 'milk', 'ground beef', 'nan'],
#  ['milk', 'ground beef', 'soup', 'nan'],
#  ['mineral water', 'ground beef', 'spaghetti', 'olive oil'],
#  ['mineral water', 'pancakes', 'ground beef', 'spaghetti'],
#  ['mineral water', 'tomatoes', 'ground beef', 'spaghetti'],
#  ['pepper', 'nan', 'ground beef', 'spaghetti'],
#  ['shrimp', 'nan', 'ground beef', 'spaghetti'],
#  ['nan', 'ground beef', 'spaghetti', 'tomato sauce'],
#  ['mineral water', 'nan', 'spaghetti', 'light cream'],
#  ['mineral water', 'milk', 'spaghetti', 'olive oil'],
#  ['mineral water', 'milk', 'spaghetti', 'tomatoes'],
#  ['olive oil', 'milk', 'shrimp', 'nan'],
#  ['olive oil', 'milk', 'soup', 'nan'],
#  ['olive oil', 'milk', 'spaghetti', 'nan'],
#  ['tomatoes', 'milk', 'soup', 'nan'],
#  ['whole wheat pasta', 'milk', 'spaghetti', 'nan'],
#  ['mineral water', 'nan', 'soup', 'olive oil'],
#  ['whole wheat pasta', 'mineral water', 'nan', 'olive oil'],
#  ['pancakes', 'nan', 'spaghetti', 'olive oil'],
#  ['nan', 'tomatoes', 'spaghetti', 'olive oil'],
#  ['nan', 'whole wheat rice', 'spaghetti', 'tomatoes'],
#  ['nan', 'chocolate', 'ground beef', 'mineral water', 'eggs'],
#  ['nan', 'frozen vegetables', 'chocolate', 'ground beef', 'mineral water'],
#  ['nan', 'frozen vegetables', 'chocolate', 'ground beef', 'spaghetti'],
#  ['milk', 'nan', 'frozen vegetables', 'chocolate', 'mineral water'],
#  ['milk', 'nan', 'frozen vegetables', 'chocolate', 'spaghetti'],
#  ['nan', 'frozen vegetables', 'chocolate', 'mineral water', 'shrimp'],
#  ['nan', 'chocolate', 'olive oil', 'mineral water', 'spaghetti'],
#  ['nan', 'chocolate', 'mineral water', 'spaghetti', 'shrimp'],
#  ['milk', 'nan', 'frozen vegetables', 'mineral water', 'eggs'],
#  ['nan', 'milk', 'mineral water', 'spaghetti', 'frozen smoothie'],
#  ['milk', 'nan', 'frozen vegetables', 'ground beef', 'mineral water'],
#  ['milk', 'nan', 'frozen vegetables', 'ground beef', 'spaghetti'],
#  ['nan', 'frozen vegetables', 'ground beef', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'frozen vegetables', 'olive oil', 'mineral water'],
#  ['milk', 'nan', 'soup', 'frozen vegetables', 'mineral water'],
#  ['milk', 'nan', 'frozen vegetables', 'mineral water', 'spaghetti'],
#  ['nan', 'frozen vegetables', 'mineral water', 'spaghetti', 'shrimp'],
#  ['nan', 'frozen vegetables', 'tomatoes', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'ground beef', 'mineral water', 'spaghetti'],
#  ['nan', 'ground beef', 'olive oil', 'mineral water', 'spaghetti'],
#  ['nan', 'ground beef', 'mineral water', 'spaghetti', 'pancakes'],
#  ['nan', 'tomatoes', 'ground beef', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'olive oil', 'mineral water', 'spaghetti'],
#  ['milk', 'nan', 'tomatoes', 'mineral water', 'spaghetti']]
