# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy='most_frequent')

# %%
df[['Age', 'Cabin' , 'Fare']] = si.fit_transform(df[['Age', 'Cabin' , 'Fare']])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# Sex            object
# Age            object
# SibSp           int64
# Parch           int64
# Ticket         object
# Fare           object
# Cabin          object
# Embarked       object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Name'] = lb.fit_transform(df['Name'])
df['Sex'] = lb.fit_transform(df['Sex'])
df['Age'] = lb.fit_transform(df['Age'])
df['Ticket'] = lb.fit_transform(df['Ticket'])
df['Fare'] = lb.fit_transform(df['Fare'])
df['Cabin'] = lb.fit_transform(df['Cabin'])
df['Embarked'] = lb.fit_transform(df['Embarked'])

# %%
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# 0           892         0       3   206    1   44      0      0     152    24
# 1           893         1       3   403    0   60      1      0     221     5
# 2           894         0       2   269    1   74      0      0      73    41
# 3           895         0       3   408    1   34      0      0     147    34
# 4           896         1       3   178    0   27      1      1     138    46
# 5           897         0       3   366    1   17      0      0     261    37
# 6           898         1       3    84    0   38      0      0     158    14
# 7           899         0       2    57    1   32      1      1      84   100
# 8           900         1       3     4    0   22      0      0     100     8
# 9           901         0       3   103    1   26      2      0     269    89
# 10          902         0       3   187    1   26      0      0     195    29
# 11          903         0       1   196    1   59      0      0     259    93
# 12          904         1       1   352    0   29      1      0      52   149
# 13          905         0       2   184    1   75      1      0      74    93
# 14          906         1       1    69    0   60      1      0     362   135
# 15          907         1       2   415    0   30      1      0     343    96
# 16          908         0       2   204    1   45      0      0      60    47
# 17          909         0       3    21    1   26      0      0     119     7
# 18          910         1       3   188    0   34      1      0     356    30
# 19          911         1       3    20    0   58      0      0     120     7
# 20          912         0       1   324    1   67      1      0     316   133
# 21          913         0       3   284    1   12      0      1     277     1
# 22          914         1       1   138    0   26      0      0     314   108
# 23          915         0       1   406    1   26      0      1     313   136
# 24          916         1       1   329    0   61      1      3     319   166
# 25          917         0       3   318    1   63      1      0     273    61
# 26          918         1       1   288    0   27      0      1      14   137
# 27          919         0       3    97    1   28      0      0     121     7
# 28          920         0       1    44    1   54      0      0      11   104
# 29          921         0       3   339    1   26      2      0     104    82
#
#     Cabin  Embarked
# 0      15         1
# 1      15         2
# 2      15         1
# 3      15         2
# 4      15         2
# 5      15         2
# 6      15         1
# 7      15         2
# 8      15         0
# 9      15         2
# 10     15         2
# 11     15         2
# 12     12         2
# 13     15         2
# 14     60         2
# 15     15         0
# 16     15         1
# 17     15         0
# 18     15         2
# 19     15         0
# 20     15         0
# 21     15         2
# 22     15         2
# 23     15         0
# 24     15         0
# 25     15         2
# 26     10         0
# 27     15         0
# 28      2         2
# 29     15         0

# %%
x = df.drop(columns = ['Survived'])
y = df['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2 , random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 1.0

# %%
print(x.columns)
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train , y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 1.0
